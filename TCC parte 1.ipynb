# %% [markdown]
# # Importação dos dados ENEM 2019

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from pandas.plotting import table

# %%
fonte = 'C:\Workspace\MICRODADOS_ENEM_2019.csv'

dados = pd.read_csv(fonte, encoding = "ISO-8859-1", sep = ';') # 'dados' é um dataframe
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA     NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004627    2019                  1506807                    Santarém
# 1  190001004628    2019                  1504059                  Mãe do Rio
# 2  190001004629    2019                  1505502                 Paragominas
# 3  190001004630    2019                  1507706  São Sebastião da Boa Vista
# 4  190001004631    2019                  1503903                      Juruti
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        21       M                1
# 1                15               PA        16       F                1
# 2                15               PA        18       F                1
# 3                15               PA        23       M                0
# 4                15               PA        23       M                1
#
# ...

# %%
dados.shape
# Out:
# (5095270, 136)

# %%
dadosCE = dados.query('SG_UF_RESIDENCIA == "CE"')

# %%
dadosCEFortaleza = dadosCE.query('NO_MUNICIPIO_RESIDENCIA == "Fortaleza"')

# %%
dadosCEFortaleza
# Out:
#          NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 2386     190001007013    2019                  2304400
# 10768    190001015395    2019                  2304400
# 32556    190001037184    2019                  2304400
# 39597    190001044225    2019                  2304400
# 55286    190001059914    2019                  2304400
# ...               ...     ...                      ...
# 5094847  190006119773    2019                  2304400
# 5094852  190006119778    2019                  2304400
# 5094857  190006119783    2019                  2304400
# 5094861  190006119787    2019                  2304400
# 5094864  190006119790    2019                  2304400
#
#         NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 2386                  Fortaleza                23               CE        22
# 10768                 Fortaleza                23               CE        20
# ...

# %%
dadosCEFortaleza.shape
# Out:
# (93959, 136)

# %%
dadosCE.to_csv ('C:\Workspace\dadosCE.csv', index = False, header=True)

# %%
dadosCEFortaleza.to_csv ('C:\Workspace\dadosCEFortaleza.csv', index = False, header=True)
